# %%
# !python -m src.run_inpaint
# Out:
# In 'config': Could not find 'data/local_images'
#
# Config search path:
# 	provider=hydra, path=pkg://hydra.conf
# 	provider=main, path=file:///workspace/configs
# 	provider=schema, path=structured://
#
# Set the environment variable HYDRA_FULL_ERROR=1 for a complete stack trace.

# %%
# !python -m src.run_inpaint sampler=repaint run.seed=42

# %%
# !python -m src.run_inpaint sampler=bar_repaint run.seed=42

# %%
# !python -m src.run_inpaint sampler=bar_repaint sampler.bar.rings=5
# !python -m src.run_inpaint sampler=bar_repaint sampler.bar.rings=6
# !python -m src.run_inpaint sampler=bar_repaint sampler.bar.rings=7

# %%
# !python -m src.run_inpaint sampler=repaint sampler.repaint.jump_every=3 sampler.repaint.p=0.2
# !python -m src.run_inpaint sampler=repaint sampler.repaint.jump_every=6 sampler.repaint.p=0.35
# !python -m src.run_inpaint sampler=repaint sampler.repaint.jump_every=10 sampler.repaint.p=0.5

# %%
# !python -m src.run_inpaint sampler=bar_repaint sampler.repaint.stop_jump_frac=0.5
# !python -m src.run_inpaint sampler=bar_repaint sampler.repaint.time_decay=false

# %%
# !python -m src.eval_lpips_celebhq
# Out:
# CLIPTextModel LOAD REPORT from: /workspace/.cache/huggingface/hub/models--sd2-community--stable-diffusion-2-inpainting/snapshots/5f74973cbb64c8568780732c17f43eb269d63a0d/text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting up [LPIPS] perceptual loss: trunk [alex], v[0.1], spatial [off]
# /opt/micromamba/envs/repaint-bar/lib/python3.11/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...
